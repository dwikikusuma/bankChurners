# %% [markdown]
# # Bank Churner Dataset

# %% [markdown]
# Dataset di ambil dari: <a href> https://www.kaggle.com/sakshigoyal7/credit-card-customers </a>

# %% [markdown]
# <h3>Business Insight</h3>
# - apakah para customer akan churn pada credit card yang mereka gunakan ?<br>
# - melakukan rekomendasi card_category sesuai data pengguna<br>
# - tindakan apa yang harus di lakukan agar mengurai churn customer<br>

# %% [markdown]
# <h3>kolom feature</h3>
# - 'CLIENTNUM'<br>
# clinet unique ID
# <br>
# <br>
# - 'Attrition_Flag' <br>
# customer akan churn(Attritired Customer) atau tidak (esxsisting customer)
# <br><br>
# - 'Customer_Age'<br>
# Umur dari customer
# <br><br>
# - 'Gender' <br>
# customer Gender
# <br><br>
# - 'Dependent_count' <br>
# brapa orang yang menggunakan kartu credit
# <br><br>
# - 'Education_Level' <br>
# pendidikan terakhir customer
# <br><br>
# - 'Marital_Status' <br>
# status pernikahan
# <br><br>
# - 'Income_Category' <br>
# jumlah pendapatan
# <br><br>
# - 'Card_Category' <br>
# tipe kartu kredit yang di gunakan
# <br><br>
# - 'Months_on_book' <br>
# jangka waktu menggunakan bank
# <br><br>
# - 'Total_Relationship_Count' <br>
# total kartu yang di gunakan customer
# <br><br>
# - 'Months_Inactive_12_mon' <br>
# kartu tidask aktif/ digunakan dalam 12 bulan terakhir
# <br><br>
# - 'Contacts_Count_12_mon'  <br>
# berapa kali customer di contac oleh bank
# <br><br>
# - 'Credit_Limit' <br>
# limit pada kartu credit
# <br><br>
# - 'Total_Revolving_Bal'<br>
# berapa tagihan dari kartu credit yang tidak di bayarkan
# <br><br>
# - 'Avg_Open_To_Buy',<br>
# rata-rata credit yang tersidea pada kartu customer selama 1 tahun
# <br><br>
# - 'Total_Amt_Chng_Q4_Q1'<br>
# berapa pengeluaran yang bertambah pada quarter ke-4 di bandingkan quarter ke-1
# <br><br>
# - 'Total_Trans_Amt'<br>
# total pengeluaran pada kartu credit selama 12 bulan
# <br><br>
# - 'Total_Trans_Ct' <br>
# total kartu credit di gunakan selama 12 bulma
# <br><br>
# - 'Total_Ct_Chng_Q4_Q1' <br>
# total berapa kali kartu di gunakan pada quarter ke-3 di bandingkan quarter ke-1
# <br><br>
# - 'Avg_Utilization_Ratio' <br>
# rata-rata credit yang di gunakan dari total credit yang di miliki (total debt/total available credit)
# <br><br>

# %% [markdown]
# > # EDA

# %% [markdown]
# #### Import unutk melakukan eda

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/BankChurners.csv')
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# ##### Tidak terdapat kolom null pada dataset

# %% [markdown]
# ### lihat uniqe value pada dataset

# %%
def desc(x):
    temp = []
    d =[]
    for i in x:
        a = data[i].unique()
        c = data[i].nunique()
        b = str(a)
        temp.append(b)
        d.append(c)
    res = pd.DataFrame(temp,index=x,columns=['unique value'])
    res['count'] = d
    return res

# %%
cek = 'Attrition_Flag','Gender','Dependent_count', 'Education_Level', 'Marital_Status','Income_Category','Card_Category'
desc(cek)
# Out:
#                                                       unique value  count
# Attrition_Flag           ['Existing Customer' 'Attrited Customer']      2
# Gender                                                   ['M' 'F']      2
# Dependent_count                                      [3 5 4 2 0 1]      6
# Education_Level  ['High School' 'Graduate' 'Uneducated' 'Unknow...      7
# Marital_Status           ['Married' 'Single' 'Unknown' 'Divorced']      4
# Income_Category  ['$60K - $80K' 'Less than $40K' '$80K - $120K'...      6
# Card_Category                  ['Blue' 'Gold' 'Silver' 'Platinum']      4

# %% [markdown]
# ## Percantage Attritation Flag

# %%
plt.figure(figsize=(10,10))
plt.pie(data['Attrition_Flag'].value_counts(), labels=data['Attrition_Flag'].unique(), autopct='%.2f')
plt.title('Churn')
plt.show()

# %% [markdown]
# terdapat 16% customer yang churn pada dataset

# %% [markdown]
# ## csutomer insight

# %% [markdown]
# # Gender

# %%
plt.figure(figsize=(10,10))
plt.pie(data['Gender'].value_counts(), labels=data['Gender'].unique(), autopct='%.2f')
plt.title('Gender')
plt.show()

# %% [markdown]
# gender pada dataset hampir seimbang

# %% [markdown]
# ### Churn By gendr

# %%
attr_g = data.groupby('Attrition_Flag')['Gender'].value_counts().to_frame().rename(columns={'Gender': 'Freq'}).reset_index().sort_values('Attrition_Flag')
plt.figure(figsize=(10,10))
sns.barplot(data=attr_g,x="Attrition_Flag",y='Freq',hue='Gender')
plt.title("Attrition By Gender")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# Gender pengguna yang melakukan churn tidak jauh berbeda

# %%
attr_g = attr_g.pivot_table('Freq',['Attrition_Flag','Gender'])
attr_g
# Out:
#                           Freq
# Attrition_Flag    Gender
# Attrited Customer F        930
#                   M        697
# Existing Customer F       4428
#                   M       4072

# %% [markdown]
# ### 2 Card

# %%
plt.figure(figsize=(10,10))
plt.pie(data['Card_Category'].value_counts(), labels=data['Card_Category'].unique(), autopct='%.2f')
plt.title('Card Category Percentile')
plt.legend()
plt.show()

# %% [markdown]
# ### 2.1 gender pada penggunaan kartu

# %%
card_g = data.groupby('Card_Category')['Gender'].value_counts().to_frame().rename(columns={'Gender':'Freq'}).reset_index().sort_values('Card_Category')
plt.figure(figsize=(10,10))
sns.barplot(data=card_g,x="Card_Category",y='Freq',hue='Gender')
plt.title("Gender card Category")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# penguna Female lebih banyak pada Blue,Silve sedangkan Male lebih banayk pada Gold

# %%
card_g =card_g.pivot_table('Freq',['Card_Category','Gender'])
card_g
# Out:
#                       Freq
# Card_Category Gender
# Blue          F       5101
#               M       4335
# Gold          F         38
#               M         78
# Platinum      F          9
#               M         11
# Silver        F        210
#               M        345

# %% [markdown]
# Jenis kartu yang paling banyak di gunkana adalah BLUE dan gender pada pengguna kartu hampir sama baik male ataupun female

# %% [markdown]
# ### 2.2 Card Attrition By Card Category

# %%
card_attr = data.groupby('Card_Category')['Attrition_Flag'].value_counts().to_frame().rename(columns={'Attrition_Flag':'Freq'}).reset_index().sort_values('Card_Category')
card_attr.pivot_table('Freq',['Attrition_Flag','Card_Category'])
# Out:
#                                  Freq
# Attrition_Flag    Card_Category
# Attrited Customer Blue           1519
#                   Gold             21
#                   Platinum          5
#                   Silver           82
# Existing Customer Blue           7917
#                   Gold             95
#                   Platinum         15
#                   Silver          473

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=card_attr,x="Card_Category",y='Freq',hue='Attrition_Flag')
plt.title("ChurnBy Card Category")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# paling banayk yang melakukan churn adalah customer yang menggunakan Blue card

# %% [markdown]
# # 3. Education level

# %%
plt.figure(figsize=(10,10))
plt.pie(data['Education_Level'].value_counts(), labels=data['Education_Level'].unique(), autopct='%.2f')
plt.title('Education Level Percentile')
plt.show()

# %% [markdown]
# penguna kartu kredit terbanyak di dapat dari High School

# %% [markdown]
# ### 3.1 Jumlah penguna Card berdasarkan education level

# %%
card_attr = data.groupby('Card_Category')['Education_Level'].value_counts().to_frame().rename(columns={'Education_Level':'Freq'}).reset_index().sort_values('Card_Category')
card_attr.pivot_table('Freq',['Education_Level','Card_Category'])
# Out:
#                                Freq
# Education_Level Card_Category
# College         Blue            940
#                 Gold             15
#                 Silver           58
# Doctorate       Blue            422
#                 Gold              5
#                 Platinum          2
#                 Silver           22
# Graduate        Blue           2899
#                 Gold             36
#                 Platinum          8
#                 Silver          185
# High School     Blue           1888
#                 Gold             26
#                 Platinum          1
#                 Silver           98
# Post-Graduate   Blue            476
#                 Gold              5
#                 Platinum          3
#                 Silver           32
# Uneducated      Blue           1391
#                 Gold             11
#                 Platinum          3
#                 Silver           82
# Unknown         Blue           1420
# ...

# %% [markdown]
# ### 3.1 Churn By Education_level

# %%
ec = data.groupby('Attrition_Flag')['Education_Level'].value_counts().to_frame().rename(columns ={'Education_Level':'Freq'}).reset_index().sort_values('Attrition_Flag')
ec = ec.pivot_table('Freq',['Attrition_Flag','Education_Level'])
ec
# Out:
#                                    Freq
# Attrition_Flag    Education_Level
# Attrited Customer College           154
#                   Doctorate          95
#                   Graduate          487
#                   High School       306
#                   Post-Graduate      92
#                   Uneducated        237
#                   Unknown           256
# Existing Customer College           859
#                   Doctorate         356
#                   Graduate         2641
#                   High School      1707
#                   Post-Graduate     424
#                   Uneducated       1250
#                   Unknown          1263

# %%
ec = data.groupby('Attrition_Flag')['Education_Level'].value_counts().to_frame().rename(columns ={'Education_Level':'Freq'}).reset_index().sort_values('Attrition_Flag')
plt.figure(figsize=(10,10))
sns.barplot(data=ec,x="Education_Level",y='Freq',hue='Attrition_Flag')
plt.title("Attrition By Education Level")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# dari data di atas penyumbang terbanyak attritired_Custumer dari education level Graduate

# %%
get = data[data['Attrition_Flag'] == "Attrited Customer"]
card_attr = get.groupby(['Card_Category','Attrition_Flag'])['Education_Level'].value_counts().to_frame().rename(columns={'Education_Level':'Freq'}).reset_index().sort_values('Card_Category')
card_attr.pivot_table('Freq',['Attrition_Flag','Education_Level','Card_Category'])
# Out:
#                                                  Freq
# Attrition_Flag    Education_Level Card_Category
# Attrited Customer College         Blue            143
#                                   Gold              1
#                                   Silver           10
#                   Doctorate       Blue             91
#                                   Gold              1
#                                   Platinum          1
#                                   Silver            2
#                   Graduate        Blue            450
#                                   Gold              6
#                                   Platinum          3
#                                   Silver           28
#                   High School     Blue            287
#                                   Gold              4
#                                   Silver           15
#                   Post-Graduate   Blue             83
# ...

# %% [markdown]
#  - Churn terbesar terjadi pada Blue Card dan tidak ada perbedaan yg signifikan atara male dan female
#  - Churn terbesar terjadi pada Graduated dengan Blue Card
#  - Penguna kartu terbanyak berasal dari High School
#
# dari poin di atas kita akan mencari lebih detail kenapa pada Blue card dengan g4raduated education level banyak mengalami churn

# %% [markdown]
# # transaction Insight

# %%
churn_data = data[data['Attrition_Flag'] == 'Attrited Customer'].copy()
exst_data = data[data['Attrition_Flag'] == 'Existing Customer'].copy()

# %%
churn_data['Months_on_book']
# Out:
# 21       49
# 39       56
# 51       40
# 54       36
# 61       35
#          ..
# 10119    47
# 10123    25
# 10124    36
# 10125    36
# 10126    25
# Name: Months_on_book, Length: 1627, dtype: int64

# %% [markdown]
# ## Churn Customer based on Month_book

# %%
plt.figure(figsize=(15,10))
plt.title('Month_on_Book distribution')
sns.distplot(data[data['Attrition_Flag'] == 'Attrited Customer']['Months_on_book'], label='Churn')
sns.distplot(data[data['Attrition_Flag'] == 'Existing Customer']['Months_on_book'], label='Exsist')
plt.legend(loc= 'upper right')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Dari plot di atas banyak terjadi chur pada pertengahan saat menggunakan credit card

# %% [markdown]
# ## Churn customer Gender based on Month_book

# %%
plt.figure(figsize=(15,10))
plt.title('Month_on_Book distribution_by_gender')
sns.distplot(data[(data['Attrition_Flag'] == 'Attrited Customer') & (data['Gender'] == 'M')]['Months_on_book'], label='Female')
sns.distplot(data[(data['Attrition_Flag'] == 'Attrited Customer') & (data['Gender'] == 'F')]['Months_on_book'], label='Male')
plt.legend(loc= 'upper right')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Churn yang terjadi anatara Male dan female memiliki polas yang sama

# %% [markdown]
#  - Churn terjadi pada pertengahan bulan tanpa dipengaruhi oleh gender

# %%
# get =data.groupby('Attrition_Flag')['Total_Relationship_Count'].value_counts().to_frame().rename(columns={'Total_Relationship_Count':'Freq'}).reset_index()
# get = get.pivot_table('Freq',['Attrition_Flag','Total_Relationship_Count']).reset_index()
# get

# %%
get =data.groupby('Attrition_Flag')['Total_Relationship_Count'].value_counts().to_frame().rename(columns={'Total_Relationship_Count':'Freq'}).reset_index()
plt.figure(figsize=(10,10))
sns.barplot(data=get,x="Total_Relationship_Count",y='Freq',hue='Attrition_Flag')
plt.title("churn by Total_Relationship_Count")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# Customer churn banyak terjadi pada Total_Relationship_count 3

# %% [markdown]
# ## Month_In_Actice

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.pie(x=churn_data['Months_Inactive_12_mon'].value_counts(),
        labels=churn_data['Months_Inactive_12_mon'].unique(), 
        autopct='%.2f')
plt.title('Churn')
plt.subplot(122)
plt.pie(x=exst_data['Months_Inactive_12_mon'].value_counts(),
        labels=exst_data['Months_Inactive_12_mon'].unique(), 
        autopct='%.2f')
plt.title('not Churn')
plt.show()

# %% [markdown]
# dari plot di atas customer yang melakukan churn akan lebih tidak aktif dalam menggunakan kartu creditnya sementara customer yang exs paling lama tidak menggunakan kartunya selama 4 bulan

# %%
plt.figure(figsize=(15,10))
plt.title('Month_in_active distribution')
sns.distplot(data[data['Attrition_Flag'] == 'Attrited Customer']['Months_Inactive_12_mon'], label='Churn')
sns.distplot(data[data['Attrition_Flag'] == 'Existing Customer']['Months_Inactive_12_mon'], label='Exsist')
plt.legend(loc= 'upper right')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Nili churn tinggi pada pengguna yang tidak aktif melakukan transaksi dalam waktu 3 bulan

# %% [markdown]
# ## 'Contacts_Count_12_mon'

# %%
plt.figure(figsize=(15,10))
plt.title('contac_count distribution')
sns.distplot(data[data['Attrition_Flag'] == 'Attrited Customer']['Contacts_Count_12_mon'], label='Churn')
sns.distplot(data[data['Attrition_Flag'] == 'Existing Customer']['Contacts_Count_12_mon'], label='Exsist')
plt.legend(loc= 'upper right')
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ## Calculate AT-Cust
# get_t = data[data['Attrition_Flag'] == 'Attrited Customer']
# get_t = get_t.groupby('Attrition_Flag')['Education_Level'].value_counts().to_frame().rename(columns ={'Education_Level':'Freq'}).reset_index().sort_values('Attrition_Flag')
# tmp_t =[]
# for i in get_t['Freq']:
#     tmp_t.append(i)


# ## Calculate EX-Cust
# get_f = data[data['Attrition_Flag'] == 'Existing Customer']
# get_f = get_f.groupby('Attrition_Flag')['Education_Level'].value_counts().to_frame().rename(columns ={'Education_Level':'Freq'}).reset_index().sort_values('Attrition_Flag')
# tmp_f = []
# for i in get_f['Freq']:
#     tmp_f.append(i)

# ## Cal Total freq
# data_2 = data.copy()
# data_2['e'] = 1 
# get = data_2[['Education_Level','e']].groupby('Education_Level').count().sort_values('e', ascending = False)

# tmp = []
# for i in get['e']:
#     tmp.append(i)

# # Cal Per5centile
# p = []
# for a, b in zip(tmp_t, tmp):
#     cal =float(a/b)*100
#     calc = '{:.2f}'.format(cal)
#     p.append(cal)
    

# print(get)
# print(tmp)
# print(tmp_t)
# print(tmp_f)
# #print(p)

# %%
# ec = data.groupby('Attrition_Flag')['Education_Level'].value_counts().to_frame().rename(columns ={'Education_Level':'Freq'}).reset_index().sort_values('Education_Level')
# #ec = ec.pivot_table('Freq',['Attrition_Flag','Education_Level'])
# tot=[]
# for i in ec['Freq'][::1]:
#     #print(i)
#     for j in ec['Freq'][1::1]:
#         if len(tot) < 14:
#         #print(j) 
#             total = i+j
#             per_i = float((i/total)*100)
#             prif = "{:.2f}".format(per_i)
#             tot.append(float(prif))
#             per_j = float((j/total)*100)
#             prij = "{:.2f}".format(per_j)
#             tot.append(float(prij))
# print(tot)
# print(ec)

# %%
x_train.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-78221869df7b> in <module>
# ----> 1 x_train.describe()
#
# NameError: name 'x_train' is not defined
